# %% [markdown]
# # Etech Consulting

# %% [markdown]
# ![Screenshot from 2022-12-05 22-08-54.png](data:image/png;base64,...)

# %% [markdown]
# # Python Programming for Beginners in 18 hours

# %% [markdown]
# - Pything Programming Language (Scripting in Python)
# - Basic Object Oriented Programming (OOP) Concepts using Python

# %% [markdown]
# Requirements
#
# - A computer with the following minimum specifications
#     - 8GB RAM
#     - 500 GB Hard Disk
#     - i5 intel core processor
#
# - Python Development Environment
#     - Download and install Anaconda from https://www.anaconda.com/products/distribution
#     - Activate Jupyter Notebook in the anaconda package
#
#     OR
#
#     - Use Jupyter Notebook environment online on Google for FREE at colab.research.google.com with a gmail account.

# %% [markdown]
# ## Outline
#
# - Programming introduction
# - Python Programming introduction
#     - Exercise (Creating Jupyter Notebook cells)
# - Variables and Data Types
#     - Exercises
#     - Mini Project (BMI of sports players)
# - Program Instructions Control Flow
#     - Exercises
#     - Mini Project (Tracking Game Scores)
# - Data Structures
#     - Recap of Data Types
#     - Lists
#     - Tuple
#     - Set
#     - Dictionary
#     - Zip
#     - Iterators
#     - Collections
#     - Exercises
#     - Mini Project
#
# - Algorithms
#     - Mini Project
# - OOP
#     - Mini Project
#
# - Main Project
